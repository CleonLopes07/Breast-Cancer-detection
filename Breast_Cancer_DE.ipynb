# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# Importing the DataSet

# %%
df=pd.read_csv("/content/drive/MyDrive/DE Tasks/breast_cancer_survival.csv")

# %% [markdown]
# df.shape to know how many columns and rows are there.

# %%
df.shape
# Out:
# (334, 15)

# %% [markdown]
# df.head and df.tail to know that all the data has been imported or not

# %%
df.head()
# Out:
#    Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0   42  FEMALE   0.95256   2.15000  0.007972 -0.048340           II
# 1   54  FEMALE   0.00000   1.38020 -0.498030 -0.507320           II
# 2   63  FEMALE  -0.52303   1.76400 -0.370190  0.010815           II
# 3   78  FEMALE  -0.87618   0.12943 -0.370380  0.132190            I
# 4   42  FEMALE   0.22611   1.74910 -0.543970 -0.390210           II
#
#                        Histology ER status PR status HER2 status Surgery_type  \
# 0  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 1  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 2  Infiltrating Ductal Carcinoma  Positive  Positive    Negative   Lumpectomy
# 3  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 4  Infiltrating Ductal Carcinoma  Positive  Positive    Positive   Lumpectomy
#
#   Date_of_Surgery Date_of_Last_Visit Patient_Status
# ...

# %%
df.tail()
# Out:
#      Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 329   59  FEMALE  0.024598   1.40050  0.024751   0.28032           II
# 330   41  FEMALE  0.100120  -0.46547  0.472370  -0.52387            I
# 331   54  FEMALE  0.753820   1.64250 -0.332850   0.85786           II
# 332   74  FEMALE  0.972510   1.42680 -0.366570  -0.10782           II
# 333   66  FEMALE  0.286380   1.39980  0.318830   0.83605           II
#
#                           Histology ER status PR status HER2 status  \
# 329   Infiltrating Ductal Carcinoma  Positive  Positive    Positive
# 330   Infiltrating Ductal Carcinoma  Positive  Positive    Positive
# 331   Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 332  Infiltrating Lobular Carcinoma  Positive  Positive    Negative
# 333   Infiltrating Ductal Carcinoma  Positive  Positive    Negative
#
#                     Surgery_type Date_of_Surgery Date_of_Last_Visit  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 334 non-null    int64
#  1   Gender              334 non-null    object
#  2   Protein1            334 non-null    float64
#  3   Protein2            334 non-null    float64
#  4   Protein3            334 non-null    float64
#  5   Protein4            334 non-null    float64
#  6   Tumour_Stage        334 non-null    object
#  7   Histology           334 non-null    object
#  8   ER status           334 non-null    object
#  9   PR status           334 non-null    object
#  10  HER2 status         334 non-null    object
#  11  Surgery_type        334 non-null    object
#  12  Date_of_Surgery     334 non-null    object
#  13  Date_of_Last_Visit  317 non-null    object
#  14  Patient_Status      321 non-null    object
# ...

# %% [markdown]
# On doing df.info, we get to know that there are 10 columns with data type as object and 5 columns with numeric data type.

# %%
df['Date_of_Surgery'] = pd.to_datetime(df['Date_of_Surgery'])
df['Date_of_Last_Visit'] = pd.to_datetime(df['Date_of_Last_Visit'])
# Out:
# <ipython-input-3-eace3e0483d5>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date_of_Surgery'] = pd.to_datetime(df['Date_of_Surgery'])
# <ipython-input-3-eace3e0483d5>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date_of_Last_Visit'] = pd.to_datetime(df['Date_of_Last_Visit'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 334 non-null    int64
#  1   Gender              334 non-null    object
#  2   Protein1            334 non-null    float64
#  3   Protein2            334 non-null    float64
#  4   Protein3            334 non-null    float64
#  5   Protein4            334 non-null    float64
#  6   Tumour_Stage        334 non-null    object
#  7   Histology           334 non-null    object
#  8   ER status           334 non-null    object
#  9   PR status           334 non-null    object
#  10  HER2 status         334 non-null    object
#  11  Surgery_type        334 non-null    object
#  12  Date_of_Surgery     334 non-null    datetime64[ns]
#  13  Date_of_Last_Visit  317 non-null    datetime64[ns]
#  14  Patient_Status      321 non-null    object
# ...

# %% [markdown]
# We successfully converted the datatype of Date_of_Surgery and Date_of_Last_Visit columns from Object datatype to DateTime datatype

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Protein1', 'Protein2', 'Protein3', 'Protein4',
#        'Tumour_Stage', 'Histology', 'ER status', 'PR status', 'HER2 status',
#        'Surgery_type', 'Date_of_Surgery', 'Date_of_Last_Visit',
#        'Patient_Status'],
#       dtype='object')

# %% [markdown]
# Label Encoding some columns that have categorical data.

# %%
df["Gender"].unique()
# Out:
# array(['FEMALE', 'MALE'], dtype=object)

# %%
df["Histology"].unique()
# Out:
# array(['Infiltrating Ductal Carcinoma', 'Infiltrating Lobular Carcinoma',
#        'Mucinous Carcinoma'], dtype=object)

# %%
df["Surgery_type"].unique()
# Out:
# array(['Other', 'Lumpectomy', 'Modified Radical Mastectomy',
#        'Simple Mastectomy'], dtype=object)

# %%
df["Patient_Status"].unique()
# Out:
# array(['Alive', 'Dead', nan], dtype=object)

# %%
df["HER2 status"].unique()
# Out:
# array(['Negative', 'Positive'], dtype=object)

# %%
df["PR status"].unique()
# Out:
# array(['Positive'], dtype=object)

# %%
df["ER status"].unique()
# Out:
# array(['Positive'], dtype=object)

# %%
df.head()
# Out:
#    Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0   42  FEMALE   0.95256   2.15000  0.007972 -0.048340           II
# 1   54  FEMALE   0.00000   1.38020 -0.498030 -0.507320           II
# 2   63  FEMALE  -0.52303   1.76400 -0.370190  0.010815           II
# 3   78  FEMALE  -0.87618   0.12943 -0.370380  0.132190            I
# 4   42  FEMALE   0.22611   1.74910 -0.543970 -0.390210           II
#
#                        Histology ER status PR status HER2 status Surgery_type  \
# 0  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 1  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 2  Infiltrating Ductal Carcinoma  Positive  Positive    Negative   Lumpectomy
# 3  Infiltrating Ductal Carcinoma  Positive  Positive    Negative        Other
# 4  Infiltrating Ductal Carcinoma  Positive  Positive    Positive   Lumpectomy
#
#   Date_of_Surgery Date_of_Last_Visit Patient_Status
# ...

# %% [markdown]
# Since columns like er status, pr status, her2 status, tumour stage, surgery type and histology have categorical data, we map and label encode them to numeric data.

# %%
from sklearn.preprocessing import LabelEncoder
df['Tumour_Stage'] = df['Tumour_Stage'].map({'I': 1, 'II': 2, 'III': 3})
df['ER status'] = df['ER status'].map({'Positive': 1, 'Negative': 0})
df['PR status'] = df['PR status'].map({'Positive': 1, 'Negative': 0})
df['HER2 status'] = df['HER2 status'].map({'Positive': 1, 'Negative': 0})
df['Patient_Status'] = df['Patient_Status'].map({'Alive': 1, 'Dead': 0})
le = LabelEncoder()

df['Surgery_type'] = le.fit_transform(df['Surgery_type'])
df['Histology'] = le.fit_transform(df['Histology'])
df.head()
# Out:
#    Age  Gender  Protein1  Protein2  Protein3  Protein4  Tumour_Stage  \
# 0   42  FEMALE   0.95256   2.15000  0.007972 -0.048340             2
# 1   54  FEMALE   0.00000   1.38020 -0.498030 -0.507320             2
# 2   63  FEMALE  -0.52303   1.76400 -0.370190  0.010815             2
# 3   78  FEMALE  -0.87618   0.12943 -0.370380  0.132190             1
# 4   42  FEMALE   0.22611   1.74910 -0.543970 -0.390210             2
#
#    Histology  ER status  PR status  HER2 status  Surgery_type Date_of_Surgery  \
# 0          0          1          1            0             2      2018-05-20
# 1          0          1          1            0             2      2018-04-26
# 2          0          1          1            0             0      2018-08-24
# 3          0          1          1            0             2      2018-11-16
# 4          0          1          1            1             0      2018-12-12
#
#   Date_of_Last_Visit  Patient_Status
# 0         2018-08-26             1.0
# ...

# %%
df.isna().sum()
# Out:
# Age                    0
# Gender                 0
# Protein1               0
# Protein2               0
# Protein3               0
# Protein4               0
# Tumour_Stage           0
# Histology              0
# ER status              0
# PR status              0
# HER2 status            0
# Surgery_type           0
# Date_of_Surgery        0
# Date_of_Last_Visit    17
# Patient_Status        13
# dtype: int64

# %%
df['Date_of_Last_Visit'].isna().sum()
# Out:
# 17

# %%
df['Patient_Status'].isna().sum()
# Out:
# 13

# %%
df.dropna(axis=0,inplace=True)

# %%
df['Patient_Status'].isna().sum()
# Out:
# 0

# %%
df['Date_of_Last_Visit'].isna().sum()
# Out:
# 0

# %% [markdown]
# This implies we have 0 null values.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# This implies we have 0 duplicate rows.

# %%
df.head(15)
# Out:
#     Age  Gender  Protein1  Protein2  Protein3  Protein4  Tumour_Stage  \
# 0    42  FEMALE  0.952560   2.15000  0.007972 -0.048340             2
# 1    54  FEMALE  0.000000   1.38020 -0.498030 -0.507320             2
# 2    63  FEMALE -0.523030   1.76400 -0.370190  0.010815             2
# 3    78  FEMALE -0.876180   0.12943 -0.370380  0.132190             1
# 4    42  FEMALE  0.226110   1.74910 -0.543970 -0.390210             2
# 5    80  FEMALE  0.466470   2.57970 -1.253700  0.151540             3
# 6    66  FEMALE -0.724860  -0.28289  0.959430  0.350900             2
# 7    36  FEMALE  0.469310   1.55260 -0.165240 -0.275990             3
# 8    58  FEMALE -1.268500   0.10613  1.135200 -0.394920             2
# 10   51  FEMALE -0.384660   0.80609 -1.627400 -0.512910             2
# 11   40  FEMALE -0.565700   1.26680 -0.293460  0.193950             2
# 12   77  FEMALE -0.206080   0.57751 -0.248560  0.000000             1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 317 entries, 0 to 333
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 317 non-null    int64
#  1   Gender              317 non-null    object
#  2   Protein1            317 non-null    float64
#  3   Protein2            317 non-null    float64
#  4   Protein3            317 non-null    float64
#  5   Protein4            317 non-null    float64
#  6   Tumour_Stage        317 non-null    int64
#  7   Histology           317 non-null    int64
#  8   ER status           317 non-null    int64
#  9   PR status           317 non-null    int64
#  10  HER2 status         317 non-null    int64
#  11  Surgery_type        317 non-null    int64
#  12  Date_of_Surgery     317 non-null    datetime64[ns]
#  13  Date_of_Last_Visit  317 non-null    datetime64[ns]
#  14  Patient_Status      317 non-null    float64
# ...

# %% [markdown]
# Here we encode the gender column as female being 1 and male as 0.

# %%
df['Gender']=df['Gender'].map({'FEMALE':1,'MALE':0})
df.head()
# Out:
#    Age  Gender  Protein1  Protein2  Protein3  Protein4  Tumour_Stage  \
# 0   42       1   0.95256   2.15000  0.007972 -0.048340             2
# 1   54       1   0.00000   1.38020 -0.498030 -0.507320             2
# 2   63       1  -0.52303   1.76400 -0.370190  0.010815             2
# 3   78       1  -0.87618   0.12943 -0.370380  0.132190             1
# 4   42       1   0.22611   1.74910 -0.543970 -0.390210             2
#
#    Histology  ER status  PR status  HER2 status  Surgery_type Date_of_Surgery  \
# 0          0          1          1            0             2      2018-05-20
# 1          0          1          1            0             2      2018-04-26
# 2          0          1          1            0             0      2018-08-24
# 3          0          1          1            0             2      2018-11-16
# 4          0          1          1            1             0      2018-12-12
#
#   Date_of_Last_Visit  Patient_Status
# 0         2018-08-26             1.0
# ...

# %%
df.corr()
# Out:
#                          Age    Gender  Protein1  Protein2  Protein3  \
# Age                 1.000000 -0.026696 -0.044541 -0.011387 -0.047362
# Gender             -0.026696  1.000000 -0.159685 -0.000406  0.017109
# Protein1           -0.044541 -0.159685  1.000000  0.223093 -0.103046
# Protein2           -0.011387 -0.000406  0.223093  1.000000 -0.407670
# Protein3           -0.047362  0.017109 -0.103046 -0.407670  1.000000
# Protein4            0.095417  0.014185  0.259171  0.084939  0.076759
# Tumour_Stage       -0.144483 -0.033881 -0.051447 -0.049881  0.019770
# Histology          -0.107611 -0.034995  0.066462  0.013074 -0.022359
# ER status                NaN       NaN       NaN       NaN       NaN
# PR status                NaN       NaN       NaN       NaN       NaN
# HER2 status        -0.068386  0.035872 -0.033544 -0.013568 -0.017628
# Surgery_type       -0.034617 -0.026380 -0.127882 -0.045292 -0.059958
# Date_of_Surgery    -0.027551 -0.022958 -0.001130  0.040933  0.052363
# ...

# %%
df['ER status'].unique()
# Out:
# array([1])

# %%
df['PR status'].unique()
# Out:
# array([1])

# %%
df=df.drop(['PR status','ER status'],axis=1)

# %% [markdown]
# Since according to the correlation map, er status and pr status have 0 correlation because all the values in those columns are 1, we drop them.

# %%
df.corr()
# Out:
#                          Age    Gender  Protein1  Protein2  Protein3  \
# Age                 1.000000 -0.026696 -0.044541 -0.011387 -0.047362
# Gender             -0.026696  1.000000 -0.159685 -0.000406  0.017109
# Protein1           -0.044541 -0.159685  1.000000  0.223093 -0.103046
# Protein2           -0.011387 -0.000406  0.223093  1.000000 -0.407670
# Protein3           -0.047362  0.017109 -0.103046 -0.407670  1.000000
# Protein4            0.095417  0.014185  0.259171  0.084939  0.076759
# Tumour_Stage       -0.144483 -0.033881 -0.051447 -0.049881  0.019770
# Histology          -0.107611 -0.034995  0.066462  0.013074 -0.022359
# HER2 status        -0.068386  0.035872 -0.033544 -0.013568 -0.017628
# Surgery_type       -0.034617 -0.026380 -0.127882 -0.045292 -0.059958
# Date_of_Surgery    -0.027551 -0.022958 -0.001130  0.040933  0.052363
# Date_of_Last_Visit -0.041302 -0.070295 -0.021326  0.013156  0.035105
# Patient_Status      0.012410  0.015509  0.019805 -0.074810 -0.025305
#
# ...

# %% [markdown]
# # **Correlation Heat Map**

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt='.1f', cmap='coolwarm').set(title='Correlation Heatmap')
plt.show()

# %% [markdown]
# According to the correlation heat map,
#
# protein1 and protein4 have a positive correlation,
#
# histology and tumour stage have a positive correlation indicating that the tissue is related to the tumour stage.
#
# On the other hand,
#
# protein2 and protein3 have a negative correlation,
#
# patient status and surgery type have a negative correlation implying that certain surgeries have a significant impact on the patient outcomes.
#
# Others show weak or no correlations.

# %% [markdown]
# # **Protein Density in Tumour Stage 1**

# %%
fig = plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
sns.distplot(df[df['Tumour_Stage']==1]['Protein1'])

plt.subplot(2,2,2)
sns.distplot(df[df['Tumour_Stage']==1]['Protein2'])

plt.subplot(2,2,3)
sns.distplot(df[df['Tumour_Stage']==1]['Protein3'])

plt.subplot(2,2,4)
sns.distplot(df[df['Tumour_Stage']==1]['Protein4'])
# Out:
# <ipython-input-59-58b8a16c9aaf>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Tumour_Stage']==1]['Protein1'])
# <ipython-input-59-58b8a16c9aaf>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Tumour_Stage']==1]['Protein2'])
# ...

# %% [markdown]
# Protein1: The distribution is roughly bell-shaped, suggesting a normal distribution.
#
# Protein2: The distribution is bell-shaped and slightly skewed to the right.
#
# Protein3: The distribution is bell-shaped and it's skewed to the left.
#
# Protein4: The distribution has two peaks. This suggests that there might be two distinct groups within this protein data. The peaks are centered around -0.5 and 0.5.

# %% [markdown]
# # **Protein Density in Tumour Stage 2**

# %%
fig = plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
sns.distplot(df[df['Tumour_Stage']==2]['Protein1'])

plt.subplot(2,2,2)
sns.distplot(df[df['Tumour_Stage']==2]['Protein2'])

plt.subplot(2,2,3)
sns.distplot(df[df['Tumour_Stage']==2]['Protein3'])

plt.subplot(2,2,4)
sns.distplot(df[df['Tumour_Stage']==2]['Protein4'])
# Out:
# <ipython-input-60-7a6a2cff5607>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Tumour_Stage']==2]['Protein1'])
# <ipython-input-60-7a6a2cff5607>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Tumour_Stage']==2]['Protein2'])
# ...

# %% [markdown]
# Protein1: The distribution is roughly bell shaped with two peaks. This is a normal distribution.
#
# Protein2: The distribution is roughly bell shaped having two peaks.
#
# Protein3: The distribution is bell shaped and slightly skewed to the right. The highest density tending to 0.
#
# Protein4: The distribution is bell shaped and centrally skewed with a single highest peak.

# %% [markdown]
# # **Protein Density in Tumour Stage 3**

# %%
fig = plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
sns.distplot(df[df['Tumour_Stage']==3]['Protein1'])

plt.subplot(2,2,2)
sns.distplot(df[df['Tumour_Stage']==3]['Protein2'])

plt.subplot(2,2,3)
sns.distplot(df[df['Tumour_Stage']==3]['Protein3'])

plt.subplot(2,2,4)
sns.distplot(df[df['Tumour_Stage']==3]['Protein4'])
# Out:
# <ipython-input-61-74c1076fef7f>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Tumour_Stage']==3]['Protein1'])
# <ipython-input-61-74c1076fef7f>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Tumour_Stage']==3]['Protein2'])
# ...

# %% [markdown]
# Protein1: The distribution is slightly skewed to the left and highest density being on the positive side of 0.
#
# Proetin2: The distribution is slightly skewed to the right and the highest density being around 1.
#
# Protein3: The distribution is central with the highest peak being on the negative side of 0.
#
# Protein4: The distribution is roughly bell shaped and observing a drop in density near -1.

# %% [markdown]
# # **Age Distribution**

# %%
x = np.random.normal(58,15,334)
plt.hist(x)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The most common age group is between 40 and 50 years old.
#
# The distribution is slightly skewed to the right, meaning there are more older people in the group compared to younger people.
#
# The data is spread out over a wide range of ages.

# %%
df["Tumour_Stage"].unique()
# Out:
# array([2, 1, 3])

# %% [markdown]
# # **Tumour Stage Distribution**

# %%
y = df['Tumour_Stage'].value_counts()
stages = ["TS2","TS1","TS3"]
plt.pie(y,labels = stages, autopct='%1.1f%%')
plt.title("Tumour Stage Distribution")
plt.legend()
plt.show()

# %% [markdown]
# Tumour Stage 2 is the most common stage, making up 56.8% of the total cases.
#
# Tumour Stage 1 is the second most common stage, accounting for 24.3% of the cases.
#
# Tumour Stage 3 is the least common stage, representing 18.9% of the cases.

# %% [markdown]
# # **HER2 Status in Each Tumour Stage**

# %%
fig = plt.figure(figsize=(5,5))

plt.subplot(1,3,1)
sns.distplot(df[df['Tumour_Stage']==1]['HER2 status'])

plt.subplot(1,3,2)
sns.distplot(df[df['Tumour_Stage']==2]['HER2 status'])

plt.subplot(1,3,3)
sns.distplot(df[df['Tumour_Stage']==3]['HER2 status'])
# Out:
# <ipython-input-78-52dfee9468db>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Tumour_Stage']==1]['HER2 status'])
# <ipython-input-78-52dfee9468db>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Tumour_Stage']==2]['HER2 status'])
# ...

# %% [markdown]
# Plot 1: The distribution is skewed to the right, with a peak near 0. This suggests that most individuals have a HER2 status of 0, with a few having higher values.
#
# Plot 2: The distribution is highly concentrated at 0, with a very narrow peak. This indicates that almost all individuals have a HER2 status of 0.
#
# Plot 3: The distribution is bimodal, with peaks near 0 and 1. This suggests that there are two distinct groups of individuals based on their HER2 status. One group has a HER2 status of 0, while the other has a HER2 status of 1.

# %%
df['Recovery_Time']=df['Date_of_Last_Visit']-df['Date_of_Surgery']
print(df['Recovery_Time'])
# Out:
# 0      98 days
# 1     274 days
# 2     593 days
# 3     620 days
# 4      24 days
#         ...
# 329   437 days
# 330   272 days
# 331   199 days
# 332     9 days
# 333   187 days
# Name: Recovery_Time, Length: 317, dtype: timedelta64[ns]

# %%
has_negative_recovery_time = (df['Recovery_Time'] < pd.Timedelta(days=0)).any()

if has_negative_recovery_time:
    print("There are recovery times less than 0 days in the dataset.")
else:
    print("All recovery times are greater than or equal to 0 days.")
# Out:
# All recovery times are greater than or equal to 0 days.

# %%
y = np.array(df['Recovery_Time'])
x = np.array(df['Age'])
plt.bar(x,y)
plt.ylabel("Recovery Time")
plt.xlabel("Age")
plt.title("Recovery Time vs Age")
plt.show()

# %% [markdown]
# # **Recovery Time in Each Tumour Stage**

# %%
fig = plt.figure(figsize=(10,8))

plt.subplot(1,3,1)
sns.distplot(df[df['Tumour_Stage']==1]['Recovery_Time'])

plt.subplot(1,3,2)
sns.distplot(df[df['Tumour_Stage']==2]['Recovery_Time'])

plt.subplot(1,3,3)
sns.distplot(df[df['Tumour_Stage']==3]['Recovery_Time'])
# Out:
# <ipython-input-52-2d3a22ca5909>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Tumour_Stage']==1]['Recovery_Time'])
# <ipython-input-52-2d3a22ca5909>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Tumour_Stage']==2]['Recovery_Time'])
# ...

# %% [markdown]
# Plot1: This distribution implies a right skewed graph with a peak near 0. Heance, implying that the recovery rate for tumour stage1 is quick, with only a few people having longer recovery rate.
#
# Plot2: This distribution is also skewed to the right but with a peak slightly shifted towards right compared to tumour stage 1. This implies that the recovery rate for tumour stage 2 is higher compared to the tumour stage1 i.e. patients with stage 2 require longer time to recover than patients with stage 1.
#
# Plot3: The distribution has two peaks, signifying two age groups, one age group having a faster recovery than the other. The peaks being at 0 and 1.5.
